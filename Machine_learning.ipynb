# %%
import pandas as pd

# %%
priceAvaibility = pd.read_csv("price_availability.csv",sep=";")

# %%
priceAvaibility.head(5)
# Out:
#    listing_id         day                       created  available  \
# 0     9810829  2018-12-08  2018-09-27 06:14:10.000+0000       True
# 1     9810829  2018-12-08  2018-09-26 19:34:02.000+0000       True
# 2    20897010  2018-12-09  2018-09-27 10:38:57.000+0000       True
# 3    20897010  2018-12-09  2018-09-27 06:10:27.000+0000       True
# 4    20897010  2018-12-09  2018-09-26 19:30:25.000+0000       True
#
#   local_currency  local_price  min_nights
# 0            EUR          160           1
# 1            EUR          160           1
# 2            EUR          172           2
# 3            EUR          172           2
# 4            EUR          172           2

# %%
listingFinal = pd.read_csv("listings_final.csv",delimiter=";")

# %%
listingFinal.head(50)
# Out:
#     Unnamed: 0  listing_id                                               name  \
# 0            0    28581061                                    La maison Clery
# 1            1      661961                studio PARIS PLACE EDITH PIAF 75020
# 2            2     1261705           chambre privée à louer @ paris oberkampf
# 3            3     1318834                     Appartement au coeur du Marais
# 4            4     1677091                                Lovely & Quiet flat
# 5            5     2157481                CENTRAL ET BIEN CONÇU,50m2+terrasse
# 6            6     1140610                      Petit atelier canal st Martin
# 7            7     5662637  Sophisticated & Sunny Opulent 1BR *Opéra *4 Gu...
# 8            8     5981388              Paris 16 - Elysées-Kléber-Trocadero /
# 9            9      149534                 GREAT WARM FULL APT LE HAUT MARAIS
# 10          10     7936602                    UNIQUE ARCHITECT DESIGNED HOUSE
# ...

# %%
priceAvaibility.isna()
# Out:
#          listing_id    day  created  available  local_currency  local_price  \
# 0             False  False    False      False           False        False
# 1             False  False    False      False           False        False
# 2             False  False    False      False           False        False
# 3             False  False    False      False           False        False
# 4             False  False    False      False           False        False
# ...             ...    ...      ...        ...             ...          ...
# 4748691       False  False    False      False           False        False
# 4748692       False  False    False      False           False        False
# 4748693       False  False    False      False           False        False
# 4748694       False  False    False      False           False        False
# 4748695       False  False    False      False           False        False
#
#          min_nights
# 0             False
# ...

# %%
result = priceAvaibility.groupby('listing_id').mean()
result.head(10)
# Out:
#             available  local_price  min_nights
# listing_id
# 5396         0.011494   102.363985    2.000000
# 7397         0.168297   110.107632   11.000000
# 9342         0.309198   396.863014    2.784736
# 10010        0.254593   136.154856    4.955381
# 10270        0.511688   105.779221    4.937662
# 11213        0.179537   157.000000    1.000000
# 11848        0.102828    84.506427    3.000000
# 14845        0.239464   129.022989    2.289272
# 16457        0.030769    83.200000    2.138462
# 16626        0.462121   125.000000    5.000000
